# %% [markdown]
# <a href="https://colab.research.google.com/github/sarasantosdev/python_dados_funcoes_estruturas_excecoes_1_aula/blob/main/python_dados_funcoes_estruturas_de_dados_excecoes_1_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas em Python

# %% [markdown]
# **Instalando biblioteca dentro do notebook**

# %%
# instalando matplotlib
# !pip install matplotlib

# %%
# instalando uma versão específica da biblioteca
# !pip install matplotlib==3.6.2

# %%
# importando a biblioteca
import matplotlib

# %%
# verificando a versão da biblioteca
matplotlib.__version__
# Out:
# '3.6.2'

# %%
# importando a biblioteca com alias
import matplotlib.pyplot as plt

# %% [markdown]
# **Utilizando uma biblioteca python**

# %%
estudantes = ["João", "Maria", "José"]
notas = [8.5, 9, 6.5]

# %% [markdown]
# **precisei atualizar porque a versão instalada estava causando conflito  de versão com matplotlib inline**

# %%
# atualizando uma biblioteca
# !pip install -U matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 55.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.6.2
#     Uninstalling matplotlib-3.6.2:
#       Successfully uninstalled matplotlib-3.6.2
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(estudantes, notas)
# Out:
# <BarContainer object of 3 artists>

# %%
estudantes.append("Ana")
estudantes
# Out:
# ['João', 'Maria', 'José', 'Ana']

# %%
# importando uma função específica de uma biblioteca
from random import choice

# %%
# utilizando help() para investigar a função
help(choice)
# Out:
# Help on method choice in module random:
#
# choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.

# %% [markdown]
# o help() nos retorna que a função choice() recebe uma sequência por parâmetro e faz uma escolha aleatória de um elemento dessa sequência

# %%
estudante_escolhido = choice(estudantes)
estudante_escolhido
# Out:
# 'João'

# %% [markdown]
# **Praticando o modo de importação e o uso de bibliotecas**

# %%
from random import randrange, sample

# %%
lista = []

for i in range(0,20):
  lista.append(randrange(100))
sample(lista, 5)
# Out:
# [91, 72, 50, 74, 59]

# %%
import math

receita = 1000
unidade = 15

print(f'{math.ceil(receita/unidade)}')
# Out:
# 67
